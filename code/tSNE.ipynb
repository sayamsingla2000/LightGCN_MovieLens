# %%
import time
import numpy as np
import pandas as pd

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
user = pd.read_csv('file_user.csv' , index_col= 0)
item = pd.read_csv('file_item.csv' , index_col= 0)
df = pd.concat([user, item])

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(user)

tsne2 = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results2 = tsne2.fit_transform(item)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 10336 samples in 0.017s...
# [t-SNE] Computed neighbors for 10336 samples in 5.890s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10336
# [t-SNE] Computed conditional probabilities for sample 2000 / 10336
# [t-SNE] Computed conditional probabilities for sample 3000 / 10336
# [t-SNE] Computed conditional probabilities for sample 4000 / 10336
# [t-SNE] Computed conditional probabilities for sample 5000 / 10336
# [t-SNE] Computed conditional probabilities for sample 6000 / 10336
# [t-SNE] Computed conditional probabilities for sample 7000 / 10336
# [t-SNE] Computed conditional probabilities for sample 8000 / 10336
# [t-SNE] Computed conditional probabilities for sample 9000 / 10336
# [t-SNE] Computed conditional probabilities for sample 10000 / 10336
# [t-SNE] Computed conditional probabilities for sample 10336 / 10336
# [t-SNE] Mean sigma: 0.032248
# ...

# %%
user['x'] = tsne_results[:,0]
user['y'] = tsne_results[:,1]
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="x", y="y",
     data=user, hue="y"
)

item['x'] = tsne_results2[:,0]
item['y'] = tsne_results2[:,1]

sns.scatterplot(
    x="x", y="y",
    data=item, markers='*'
)
